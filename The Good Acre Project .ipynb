# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
dataset = pd.read_csv("/Users/kristinaserova/Desktop/For Regression Analysis .csv")

# %%
dataset.keys()
# Out:
# Index(['Producer Code', 'Success_for_2021', 'Success_for_2022', 'Own_Lands',
#        'Access _to_Water', 'Profit ', 'Lands', 'Water'],
#       dtype='object')

# %%
dataset = dataset.drop(4)
dataset = dataset.drop(2)
dataset = dataset.drop(35)

# %%
x=41
y=51
dataset.loc[x:y]
dataset.loc[x:y].index
dataset.drop(dataset.loc[x:y].index, inplace=True)

# %%
dataset['Percentage'] = dataset['Success_for_2022']*100

# %%
dataset.describe()
# Out:
#        Success_for_2021  Success_for_2022     Profit       Lands      Water  \
# count         16.000000         38.000000   38.000000  38.000000  38.000000
# mean           0.958750          0.616842  190.855000   0.315789   0.342105
# std            0.459621          0.257809  132.695303   0.471069   0.480783
# min            0.440000          0.000000   20.200000   0.000000   0.000000
# 25%            0.717500          0.505000  101.425000   0.000000   0.000000
# 50%            0.840000          0.655000  142.250000   0.000000   0.000000
# 75%            1.007500          0.770000  285.580000   1.000000   1.000000
# max            2.000000          1.140000  575.720000   1.000000   1.000000
#
#        Percentage
# count   38.000000
# mean    61.684211
# std     25.780891
# min      0.000000
# 25%     50.500000
# 50%     65.500000
# 75%     77.000000
# max    114.000000

# %%
dataset
# Out:
#    Producer Code  Success_for_2021  Success_for_2022 Own_Lands  \
# 0            AGF              0.68              0.70      True
# 1            AFC               NaN              0.71      True
# 3            CAL               NaN              0.00      True
# 5            CBS              0.73              0.45      True
# 6            CMA               NaN              0.73     False
# 7            CTH               NaN              0.60     False
# 8            CMU               NaN              0.90     False
# 9            CHO              0.77              0.31      True
# 10           CLP              0.92              0.55      True
# 11           D2D              0.65              0.72      True
# 12           DTF              0.45              0.71      True
# 13           HAF              0.82              0.69      True
# 14           YMF              0.79              0.64     False
# 15           HOP               NaN              1.00     False
# ...

# %%
y = dataset.iloc[:, 5:6].values
X = dataset.iloc[:, 8:9].values

# %%
dataset.iloc[:, 5:6].values
# Out:
# array([[205.87],
#        [112.72],
#        [116.04],
#        [250.33],
#        [384.28],
#        [ 40.48],
#        [159.95],
#        [384.28],
#        [322.51],
#        [407.06],
#        [ 82.72],
#        [186.01],
#        [575.72],
#        [ 48.96],
#        [106.18],
#        [130.91],
#        [ 20.2 ],
#        [297.33],
#        [ 99.84],
#        [ 42.3 ],
#        [143.26],
#        [ 96.14],
#        [231.3 ],
#        [108.1 ],
#        [ 50.8 ],
#        [ 86.51],
#        [316.4 ],
#        [434.  ],
#        [106.75],
#        [391.33],
#        [319.86],
#        [141.24],
#        [195.54],
#        [166.03],
#        [135.78],
#        [115.12],
#        [ 96.  ],
#        [144.64]])

# %%
dataset.iloc[:, 8:9].values
# Out:
# array([[ 70.],
#        [ 71.],
#        [  0.],
#        [ 45.],
#        [ 73.],
#        [ 60.],
#        [ 90.],
#        [ 31.],
#        [ 55.],
#        [ 72.],
#        [ 71.],
#        [ 69.],
#        [ 64.],
#        [100.],
#        [ 77.],
#        [ 50.],
#        [  0.],
#        [ 42.],
#        [ 63.],
#        [ 25.],
#        [ 89.],
#        [ 70.],
#        [ 67.],
#        [ 77.],
#        [ 30.],
#        [ 86.],
#        [ 78.],
#        [ 88.],
#        [ 56.],
#        [ 62.],
#        [ 77.],
#        [ 52.],
#        [ 52.],
#        [ 14.],
#        [114.],
#        [100.],
#        [ 57.],
#        [ 47.]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3)

# %%
dataset
# Out:
#    Producer Code  Success_for_2021  Success_for_2022 Own_Lands  \
# 0            AGF              0.68              0.70      True
# 1            AFC               NaN              0.71      True
# 3            CAL               NaN              0.00      True
# 5            CBS              0.73              0.45      True
# 6            CMA               NaN              0.73     False
# 7            CTH               NaN              0.60     False
# 8            CMU               NaN              0.90     False
# 9            CHO              0.77              0.31      True
# 10           CLP              0.92              0.55      True
# 11           D2D              0.65              0.72      True
# 12           DTF              0.45              0.71      True
# 13           HAF              0.82              0.69      True
# 14           YMF              0.79              0.64     False
# 15           HOP               NaN              1.00     False
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')

# %%
regressor.predict([[70]])
# Out:
# array([[189.94837224]])

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [[0.65973035]]
# [143.76724767]

# %%
dataset
# Out:
#    Producer Code  Success_for_2021  Success_for_2022 Own_Lands  \
# 0            AGF              0.68              0.70      True
# 1            AFC               NaN              0.71      True
# 3            CAL               NaN              0.00      True
# 5            CBS              0.73              0.45      True
# 6            CMA               NaN              0.73     False
# 7            CTH               NaN              0.60     False
# 8            CMU               NaN              0.90     False
# 9            CHO              0.77              0.31      True
# 10           CLP              0.92              0.55      True
# 11           D2D              0.65              0.72      True
# 12           DTF              0.45              0.71      True
# 13           HAF              0.82              0.69      True
# 14           YMF              0.79              0.64     False
# 15           HOP               NaN              1.00     False
# ...

# %%
newdataset = dataset[['Producer Code', 'Success_for_2022','Lands','Water','Profit ']]

# %%
newdataset
# Out:
#    Producer Code  Success_for_2022  Lands  Water  Profit
# 0            AGF              0.70    1.0    1.0   205.87
# 1            AFC              0.71    1.0    1.0   112.72
# 3            CAL              0.00    1.0    1.0   116.04
# 5            CBS              0.45    1.0    1.0   250.33
# 6            CMA              0.73    0.0    0.0   384.28
# 7            CTH              0.60    0.0    0.0    40.48
# 8            CMU              0.90    0.0    0.0   159.95
# 9            CHO              0.31    1.0    0.0   384.28
# 10           CLP              0.55    1.0    0.0   322.51
# 11           D2D              0.72    1.0    1.0   407.06
# 12           DTF              0.71    1.0    0.0    82.72
# 13           HAF              0.69    1.0    0.0   186.01
# 14           YMF              0.64    0.0    1.0   575.72
# 15           HOP              1.00    0.0    1.0    48.96
# 16           ONC              0.77    0.0    0.0   106.18
# ...

# %%
newdataset.corr()
# Out:
#                   Success_for_2022     Lands     Water   Profit
# Success_for_2022          1.000000 -0.196307 -0.019395  0.112663
# Lands                    -0.196307  1.000000  0.345441  0.000904
# Water                    -0.019395  0.345441  1.000000 -0.038218
# Profit                    0.112663  0.000904 -0.038218  1.000000

# %%
products_dataset = pd.read_excel("/Users/kristinaserova/Desktop/Hackaton/Work with Data.xlsx")

# %%
products_dataset
# Out:
#                Products   Total Margin
# 0                  Beans       7260.98
# 1                  Beets       2630.83
# 2               Bok Choy       2524.48
# 3               Broccoli        769.92
# 4       Brussels Sprouts        366.56
# 5                Cabbage       1920.02
# 6                Carrots       7279.44
# 7            Cauliflower        159.39
# 8                 Celery        175.92
# 9              Cilantro           0.00
# 10  Cranberries, organic        277.75
# 11             Cucumbers       2654.08
# 12              Eggplant       4518.75
# 13                Fennel        138.60
# 14         Garlic Scapes        158.40
# 15                 Chard       1459.50
# 16               Collard       3209.76
# 17       Eggplant Leaves       2211.00
# 18                  Kale       3561.28
# 19               Lettuce       2729.43
# 20               Malabar       2217.80
# 21               Mustard       2593.00
# 22          Pumpkin Vine       2223.06
# ...
